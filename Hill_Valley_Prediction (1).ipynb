# %% [markdown]
# # **Hill Valley Prediction**

# %% [markdown]
# ### **Objective**: To predict for Hill or Valley using logistic Regression

# %% [markdown]
# ### **Data Source**: The dataset is from YBI FOUNDATION GITHUB.
# https://github.com/YBIFoundation/Dataset/raw/main/Hill%20Valley%20Dataset.csv

# %% [markdown]
# **Import Library**

# %%
import pandas as pd

# %% [markdown]
# **Import Data**

# %%
Hill_valley = pd.read_csv("https://github.com/YBIFoundation/Dataset/raw/main/Hill%20Valley%20Dataset.csv")

# %% [markdown]
# **Describe Data**

# %%
Hill_valley.describe()
# Out:
#                   V1             V2             V3             V4  \
# count    1212.000000    1212.000000    1212.000000    1212.000000
# mean     8169.091881    8144.306262    8192.653738    8176.868738
# std     17974.950461   17881.049734   18087.938901   17991.903982
# min         0.920000       0.900000       0.850000       0.890000
# 25%        19.602500      19.595000      18.925000      19.277500
# 50%       301.425000     295.205000     297.260000     299.720000
# 75%      5358.795000    5417.847500    5393.367500    5388.482500
# max    117807.870000  108896.480000  119031.350000  110212.590000
#
#                   V5             V6             V7             V8  \
# count    1212.000000    1212.000000    1212.000000    1212.000000
# mean     8128.297211    8173.030008    8188.582748    8183.641543
# std     17846.757963   17927.114105   18029.562695   18048.582159
# min         0.880000       0.860000       0.870000       0.650000
# ...

# %%
Hill_valley.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1212 entries, 0 to 1211
# Columns: 101 entries, V1 to Class
# dtypes: float64(100), int64(1)
# memory usage: 956.5 KB

# %%
Hill_valley.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0     39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1      1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2  68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3  44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4      5.70      5.40      5.28      5.38      5.27      5.61      6.00
#
#          V8        V9       V10  ...       V92       V93       V94       V95  \
# 0     39.53     38.81     38.79  ...     36.62     36.92     38.80     38.52
# 1      1.70      1.75      1.78  ...      1.80      1.79      1.77      1.74
# 2  73268.61  74465.84  72503.37  ...  73438.88  71053.35  71112.62  74916.48
# 3  37668.32  40980.89  38466.15  ...  42625.67  40684.20  46960.73  44546.80
# 4      5.38      5.34      5.87  ...      5.17      5.67      5.60      5.94
#
#         V96       V97       V98       V99      V100  Class
# ...

# %%
Hill_valley.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        ...
#        'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'V100',
#        'Class'],
#       dtype='object', length=101)

# %% [markdown]
# **Data Preprocessing**

# %%
HVP = Hill_valley.dropna()
HVP
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0        39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1         1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2     68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3     44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4         5.70      5.40      5.28      5.38      5.27      5.61      6.00
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207     13.00     12.87     13.27     13.04     13.19     12.53     14.31
# 1208     48.66     50.11     48.55     50.43     50.09     49.67     48.95
# 1209  10160.65   9048.63   8994.94   9514.39   9814.74  10195.24  10031.47
# 1210     34.81     35.07     34.98     32.37     34.16     34.03     33.31
# 1211   8489.43   7672.98   9132.14   7985.73   8226.85   8554.28   8838.87
#
# ...

# %%
HVP = HVP.drop_duplicates()
HVP
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# 0        39.02     36.49     38.20     38.85     39.38     39.74     37.02
# 1         1.83      1.71      1.77      1.77      1.68      1.78      1.80
# 2     68177.69  66138.42  72981.88  74304.33  67549.66  69367.34  69169.41
# 3     44889.06  39191.86  40728.46  38576.36  45876.06  47034.00  46611.43
# 4         5.70      5.40      5.28      5.38      5.27      5.61      6.00
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207     13.00     12.87     13.27     13.04     13.19     12.53     14.31
# 1208     48.66     50.11     48.55     50.43     50.09     49.67     48.95
# 1209  10160.65   9048.63   8994.94   9514.39   9814.74  10195.24  10031.47
# 1210     34.81     35.07     34.98     32.37     34.16     34.03     33.31
# 1211   8489.43   7672.98   9132.14   7985.73   8226.85   8554.28   8838.87
#
# ...

# %%
HVP.groupby('Class').mean()
# Out:
#                 V1           V2           V3           V4           V5  \
# Class
# 0      7913.333251  7825.339967  7902.497294  7857.032079  7775.610198
# 1      8424.850512  8463.272558  8482.810182  8496.705396  8480.984224
#
#                 V6           V7           V8           V9          V10  ...  \
# Class                                                                   ...
# 0      7875.436337  7804.166584  7722.324802  7793.328416  7686.782046  ...
# 1      8470.623680  8572.998911  8644.958284  8516.011716  8554.753102  ...
#
#                V91          V92          V93          V94          V95  \
# Class
# 0      7753.427244  7737.843366  7799.332079  7825.211700  7791.354010
# 1      8478.513399  8502.270264  8452.502739  8492.375924  8490.416832
#
#                V96          V97          V98          V99         V100
# Class
# 0      7927.237112  7874.502343  7844.227459  7875.338713  7855.181172
# ...

# %% [markdown]
# **Define Target Variable (y) and Feature Variables (X)**

# %%
x = HVP.drop('Class', axis=1)

# %%
y = HVP['Class']

# %%
x.shape
# Out:
# (1212, 100)

# %%
y.shape
# Out:
# (1212,)

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, Y_train, Y_test = train_test_split(x,y, train_size=0.8, random_state=2529)

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Fit Transformation**

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)

# %% [markdown]
# **Modeling**

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(solver='saga',max_iter=2000)

# %%
model.fit(x_train_scaled, Y_train)
# Out:
# LogisticRegression(max_iter=2000, solver='saga')

# %% [markdown]
# **Model Evaluation**

# %%
model.intercept_
# Out:
# array([-0.00423105])

# %%
model.coef_
# Out:
# array([[-1.89576793, -1.56468638, -1.60500978, -1.43611064, -1.41974721,
#         -1.34659283, -0.63073963, -0.34184698, -0.56770194,  0.09976037,
#          0.38875779,  0.33552919,  0.73806646,  0.60621747,  1.14209342,
#          0.40745303,  0.09820871,  0.57027893,  0.24743143,  0.33158259,
#          0.11860427, -0.13336531,  0.21887651,  0.20806995,  0.11353638,
#          0.40256292,  0.1995759 ,  0.28059202,  0.28626488,  0.16246017,
#          0.40190691,  0.22723188,  0.65456106,  0.18761292,  0.15951861,
#          0.3725526 ,  0.26670122, -0.03355901,  0.37266966,  0.01881487,
#          0.54902009,  0.38735988,  0.46620935,  0.34322871,  0.33136216,
#          0.52954847,  0.22045192, -0.06348446,  0.12993563,  0.51057227,
#          0.2065595 ,  0.17508156,  0.36785849,  0.33787178,  0.43567847,
#          0.45671981,  0.04219791,  0.26462873,  0.17652934,  0.38494484,
#          0.03551195,  0.29629233,  0.50087186,  0.14714167,  0.25599476,
# ...

# %% [markdown]
# **Prediction**

# %%
Y_pred = model.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(Y_test, Y_pred)
# Out:
# 0.9300411522633745

# %% [markdown]
# **Data Visualization**

# %%
from sklearn.metrics import confusion_matrix

# %%
cf_matrix = confusion_matrix(Y_test, Y_pred)

# %%
cf_matrix
# Out:
# array([[108,  10],
#        [  7, 118]])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = sns.heatmap(cf_matrix, annot=True, cmap='Blues')
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
ax.xaxis.set_ticklabels(['False','True'])
ax.yaxis.set_ticklabels(['False','True'])
plt.show()

# %% [markdown]
# **Explaination**

# %% [markdown]
# **Library Importation**:
# I have begun by bringing in the essential libraries: pandas, train_test_split from sklearn.model_selection, StandardScaler from sklearn.preprocessing, LogisticRegression from sklearn.linear_model, accuracy_score from sklearn.metrics, seaborn, and matplotlib.pyplot.
#
# **Data Description**:
# Using pandas, I portrayed my information by analyzing the columns, data, head, and portray strategies. This gives a nitty gritty diagram of the dataset's structure and contents.
#
# **Data Cleaning**:
# I cleaned the dataset by evacuating NaN values and copies, guaranteeing that the information was precise and prepared for analysis.
#
# **Data Gathering and Aggregation**:
# I performed a groupby operation taken after by calculating the cruel of my numerical information, which made a difference in understanding the dissemination and central propensities of my features.
#
# **Defining Factors and Train-Test Split**:
# I characterized the target variable (y) and included factors (X). At that point, I divided the dataset into preparing and testing sets utilizing train_test_split, which permitted me to assess the demonstration on concealed data.
#
# **Data Standardization**:
# I utilized StandardScaler to fit and change the information, guaranteeing that all included factors were on a comparative scale, which is vital for calculated regression.
#
# **Model Choice and Training**:
# I chose Calculated Relapse as my show and prepared it utilizing the prepared information. This included fitting the logistic relapse demonstration to memorize the data.
#
# **Model Evaluation**:
# I assessed the model's execution utilizing accuracy_score, accomplishing a noteworthy exactness of 0.9300411522633745. This demonstrated that the demonstration was profoundly successful at foreseeing the target variable.
#
# **Data Visualization**:
# I utilized Seaborn and Matplotlib for data visualization, counting making a disarray network to imagine the model's execution and get its precision in classifying the data.
#
# **Summary**:
# I effectively built and assessed a calculated relapse show for slope valley expectation. By bringing in essential libraries, portraying and cleaning the information, performing groupby and cruel operations, characterizing factors, part the information, standardizing highlights, preparing the show, and assessing its execution, I accomplished a tall exactness score. Information visualization encourages and upholds the demonstrated assessment. This comprehensive approach guaranteed a strong and compelling prescient demonstration.
